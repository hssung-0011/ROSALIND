# %% [markdown]
# **Enumerating k-mers Lexicographically**

# %% [markdown]
# Assume that an alphabet A has a predetermined order; that is, we write the alphabet as a permutation A=(a1,a2,…,ak), where a1<a2<⋯<ak. For instance, the English alphabet is organized as (A,B,…,Z).
#
# Given two strings s and t having the same length n, we say that s precedes t in the lexicographic order (and write s<Lext) if the first symbol s[j] that doesn't match t[j] satisfies sj<tj in A

# %%
filepath = "/mnt/c/Data/ROSALIND_download/rosalind_lexf.txt"
with open(filepath) as f:
    data = f.read().strip().split('\n')
    chrs = [i for i in data[0].split()]
    num = int(data[1])
print(chrs, num)
# Out:
# ['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H'] 3

# %%
def ordering(curr_list, alphabets = chrs):
    result_list = []
    for i in curr_list:
        temp_list = [i + j for j in alphabets]
        result_list.extend(temp_list)
        
    return result_list

# %%
result_list = chrs
for i in range(num-1):
    result_list = ordering(result_list)

# %%
print('\n'.join(result_list))
# Out:
# AAA
# AAB
# AAC
# AAD
# AAE
# AAF
# AAG
# AAH
# ABA
# ABB
# ABC
# ABD
# ABE
# ABF
# ABG
# ABH
# ACA
# ACB
# ACC
# ACD
# ACE
# ACF
# ACG
# ACH
# ADA
# ADB
# ADC
# ADD
# ADE
# ADF
# ADG
# ADH
# AEA
# AEB
# AEC
# AED
# AEE
# AEF
# AEG
# AEH
# AFA
# AFB
# AFC
# AFD
# AFE
# AFF
# AFG
# AFH
# AGA
# AGB
# AGC
# AGD
# AGE
# AGF
# AGG
# AGH
# AHA
# AHB
# AHC
# AHD
# AHE
# AHF
# AHG
# AHH
# BAA
# BAB
# BAC
# BAD
# BAE
# BAF
# BAG
# BAH
# BBA
# BBB
# BBC
# BBD
# BBE
# BBF
# BBG
# BBH
# BCA
# BCB
# BCC
# BCD
# BCE
# BCF
# BCG
# BCH
# BDA
# BDB
# BDC
# BDD
# BDE
# BDF
# BDG
# BDH
# BEA
# BEB
# BEC
# BED
# BEE
# BEF
# BEG
# BEH
# BFA
# BFB
# BFC
# BFD
# BFE
# BFF
# BFG
# BFH
# BGA
# BGB
# BGC
# BGD
# BGE
# BGF
# BGG
# BGH
# BHA
# BHB
# BHC
# BHD
# BHE
# BHF
# BHG
# BHH
# CAA
# CAB
# CAC
# CAD
# CAE
# CAF
# CAG
# CAH
# CBA
# CBB
# CBC
# CBD
# CBE
# CBF
# CBG
# CBH
# CCA
# CCB
# CCC
# CCD
# CCE
# CCF
# CCG
# CCH
# CDA
# CDB
# CDC
# CDD
# CDE
# CDF
# CDG
# CDH
# CEA
# CEB
# CEC
# CED
# CEE
# CEF
# CEG
# CEH
# CFA
# CFB
# CFC
# CFD
# CFE
# CFF
# CFG
# CFH
# CGA
# CGB
# CGC
# CGD
# CGE
# CGF
# CGG
# CGH
# CHA
# CHB
# CHC
# CHD
# CHE
# CHF
# CHG
# CHH
# DAA
# DAB
# DAC
# DAD
# DAE
# DAF
# DAG
# DAH
# DBA
# DBB
# DBC
# DBD
# DBE
# DBF
# DBG
# DBH
# DCA
# DCB
# DCC
# DCD
# DCE
# DCF
# DCG
# DCH
# DDA
# DDB
# DDC
# DDD
# DDE
# DDF
