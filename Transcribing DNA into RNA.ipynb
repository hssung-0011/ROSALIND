# %%
DNA="..."


RNA=""

# for i in range(len(DNA)):
#     if DNA[i] == "T":
#         DNA[i] = "U"
    
#     # DNA[i] = "U" if DNA[i] == "T"
    
for i in DNA:
    if i == "T":
        RNA += "U"
    else:
        RNA += i
print(RNA)
# Out:
# ...

# %%
DNA="..."
DNA.replace("T", "U")
DNA
# Out:
# '...'
